# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import learning_curve
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
import confusion_matrix_pretty_print as cmpp

# %%
X_train = pd.read_csv('../subset/X_winetrain.csv', index_col=0)
X_test = pd.read_csv('../subset/X_winetest.csv', index_col=0)
y_train = pd.read_csv('../subset/y_winetrain.csv', header=None, index_col=0, squeeze=True)
y_test = pd.read_csv('../subset/y_winetest.csv', header=None, index_col=0, squeeze=True)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5197, 11)
# (5197,)
# (1300, 11)
# (1300,)

# %%
clf = KNeighborsClassifier(n_neighbors=8)

# %%
# %time clf.fit(X_train,y_train)
# Out:
# CPU times: user 7.19 ms, sys: 2.95 ms, total: 10.1 ms
# Wall time: 8.9 ms
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#            weights='uniform')

# %%
y_pred = clf.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.4653846153846154

# %%
y_test.value_counts()
# Out:
# 1    654
# 0    399
# 2    247
# Name: 1, dtype: int64

# %% [markdown]
# # Null Accuracy

# %%
y_test.value_counts().head(1) / y_test.count()
# Out:
# 1    0.503077
# Name: 1, dtype: float64

# %% [markdown]
# # Confusion Matrix

# %%
cm = metrics.confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[215 148  36]
#  [212 304 138]
#  [ 69  92  86]]

# %%
labels = ['Ok','Good','Great']
df_cm = pd.DataFrame(cm, index=labels, columns=labels)

# %%
cmpp.pretty_plot_confusion_matrix(df_cm, cmap="Blues_r", show_null_values=1, pred_val_axis='x')

# %%
cm.sum(axis=1)
# Out:
# array([399, 654, 247])

# %%
np.diag(cm)
# Out:
# array([215, 304,  86])

# %%
cm.sum(axis=1) - np.diag(cm)
# Out:
# array([184, 350, 161])

# %% [markdown]
# ## When Actual = Rows and Predicted = Columns
# ## TP: Diagonal top left to bottom right
# ## TN: Values in all columns and rows excluding given Class column and row
# ## FP: Values in column excluding TP
# ## FN: Values in row excluding TP

# %%
TP = np.diag(cm)
FP = cm.sum(axis=0) - np.diag(cm)
FN = cm.sum(axis=1) - np.diag(cm)
TN = cm.sum() - (TP + FP + FN)

print(TP)
print(FP)
print(FN)
print(TN)
# Out:
# [215 304  86]
# [281 240 174]
# [184 350 161]
# [620 406 879]

# %% [markdown]
# ## Accuracy: How often correct?  _Diagonal / Total_

# %%
print(metrics.accuracy_score(y_test,y_pred))
print(TP.sum() / cm.sum())
# Out:
# 0.4653846153846154
# 0.4653846153846154

# %% [markdown]
# ## Classification Error: How often incorrect? _Non-Diagonal / Total_

# %%
print(1 - metrics.accuracy_score(y_test,y_pred))
print((cm.sum() - np.diag(cm).sum()) / cm.sum())
# Out:
# 0.5346153846153846
# 0.5346153846153846

# %% [markdown]
# ## Precision: When a positive value is predicted, how often is it correct? _TP / Column Total_

# %%
print(metrics.precision_score(y_test,y_pred, average=None))
print(TP / (TP + FP))
# Out:
# [0.43346774 0.55882353 0.33076923]
# [0.43346774 0.55882353 0.33076923]

# %% [markdown]
# ## Sensitivity (Recall or TPR): When actual value is positive, how often is prediction correct? _TP / Row Total_

# %%
print(metrics.recall_score(y_test,y_pred, average=None))
print(TP/(TP+FN))
# Out:
# [0.53884712 0.4648318  0.34817814]
# [0.53884712 0.4648318  0.34817814]

# %% [markdown]
# ## False Positive Rate FP / float(TN + FP)
# =1 - Specificty

# %%
print(FP / (TN + FP))
# Out:
# [0.31187569 0.37151703 0.16524217]

# %% [markdown]
# ## Specifity TN / float(TN + FP)
# When the actual value is negative, how often is the prediction correct?

# %%
print(TN / (TN + FP))
print([1,1,1] - (FP / (TN + FP)))
# Out:
# [0.68812431 0.62848297 0.83475783]
# [0.68812431 0.62848297 0.83475783]

# %%
metrics.matthews_corrcoef(y_test,y_pred)
# Out:
# 0.15889358184297234

# %% [markdown]
# #### https://www.researchgate.net/post/Multiclass_Confusion_Matrix_Explanation

# %%
X_train.shape
# Out:
# (5197, 11)

# %%
X = pd.read_csv('../subset/X_wine.csv', index_col=0)
y = pd.read_csv('../subset/y_wine.csv', header=None, index_col=0, squeeze=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (6497, 11)
# (6497,)

# %%
print(clf)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
train_sizes = [50,520,1300,2600,3900,5196]
train_sizes, train_scores, validation_scores = learning_curve(estimator=clf,X=X, y=y, train_sizes=train_sizes, cv=5, scoring='accuracy')

# %%
print(train_scores)
print(validation_scores)
# Out:
# [[1.         0.78       0.78       0.78       0.78      ]
#  [0.76730769 0.74038462 0.74038462 0.74038462 0.74038462]
#  [0.69384615 0.70230769 0.70461538 0.70461538 0.70461538]
#  [0.69769231 0.705      0.68346154 0.67884615 0.67884615]
#  [0.70179487 0.71051282 0.68589744 0.68923077 0.68717949]
#  [0.70073133 0.70727483 0.6895689  0.68571978 0.69322556]]
# [[0.36664105 0.35153846 0.36643572 0.37105466 0.36671803]
#  [0.36510377 0.32846154 0.36489607 0.39414935 0.37365177]
#  [0.36664105 0.27769231 0.36181678 0.39568899 0.37673344]
#  [0.377402   0.37076923 0.42494226 0.43494996 0.43220339]
#  [0.37893928 0.41153846 0.44726713 0.43648961 0.43682589]
#  [0.38662567 0.39076923 0.43879908 0.45265589 0.43913713]]

# %%
train_scores_mean = train_scores.mean(axis=1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
print(pd.Series(train_scores_mean, index=train_sizes))
print()
print(pd.Series(validation_scores_mean, index=train_sizes))
# Out:
# 50      0.824000
# 520     0.745769
# 1300    0.702000
# 2600    0.688769
# 3900    0.694923
# 5196    0.695304
# dtype: float64
#
# 50      0.364478
# 520     0.365252
# 1300    0.355715
# 2600    0.408053
# 3900    0.422212
# 5196    0.421597
# dtype: float64

# %%
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label='Training error')
plt.plot(train_sizes, validation_scores_mean, label='Validation Error')

plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for Decision Tree', fontsize = 18, y=1.03)
plt.legend()

# %%
train_sizes, train_scores, validation_scores = learning_curve(estimator=clf,X=X, y=y, train_sizes=train_sizes, cv=5, scoring='accuracy')

# %%
train_scores_mean = train_scores.mean(axis=1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label='Training error')
plt.plot(train_sizes, validation_scores_mean, label='Validation Error')

plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for Decision Tree', fontsize = 18, y=1.03)
plt.legend()

# %%
k_range = range(1,31)
weight_options = ['uniform','distance']

param_grid = dict(n_neighbors=k_range, weights=weight_options)

# %%
grid = GridSearchCV(clf, param_grid, scoring='accuracy')

# %%
grid.fit(X,y)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_neighbors': range
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  2       uniform
# 3                  2      distance
# 4                  3       uniform
# 5                  3      distance
# 6                  4       uniform
# 7                  4      distance
# 8                  5       uniform
# 9                  5      distance
# 10                 6       uniform
# 11                 6      distance
# 12                 7       uniform
# 13                 7      distance
# 14                 8       uniform
# 15                 8      distance
# 16                 9       uniform
# 17                 9      distance
# 18                10       uniform
# 19                10      distance
# 20                11       uniform
# 21                11      distance
# 22                12       uniform
# 23                12      distance
# 24                13       uniform
# 25                13      distance
# 26                14       uniform
# 27                14      distance
# 28                15       uniform
# 29                15      distance
# 30                16       uniform
# 31                16      distance
# 32                17       uniform
# 33                17      distance
# 34                18       uniform
# 35                18      distance
# 36                19       uniform
# 37                19      distance
# 38                20       uniform
# 39                20      distance
# 40                21       uniform
# 41                21      distance
# 42                22       uniform
# 43                22      distance
# 44                23       uniform
# 45                23      distance
# 46                24       uniform
# 47                24      distance
# 48                25       uniform
# 49                25      distance
# 50                26       uniform
# 51                26      distance
# 52                27       uniform
# 53                27      distance
# 54                28       uniform
# 55                28      distance
# 56                29       uniform
# 57                29      distance
# 58                30       uniform
# 59                30      distance
#
#                                         params  split0_test_score  \
# 0     {'n_neighbors': 1, 'weights': 'uniform'}           0.405168
# 1    {'n_neighbors': 1, 'weights': 'distance'}           0.405168
# 2     {'n_neighbors': 2, 'weights': 'uniform'}           0.377942
# 3    {'n_neighbors': 2, 'weights': 'distance'}           0.405168
# 4     {'n_neighbors': 3, 'weights': 'uniform'}           0.399169
# 5    {'n_neighbors': 3, 'weights': 'distance'}           0.403784
# 6     {'n_neighbors': 4, 'weights': 'uniform'}           0.399631
# 7    {'n_neighbors': 4, 'weights': 'distance'}           0.399169
# 8     {'n_neighbors': 5, 'weights': 'uniform'}           0.424089
# 9    {'n_neighbors': 5, 'weights': 'distance'}           0.404707
# 10    {'n_neighbors': 6, 'weights': 'uniform'}           0.411629
# 11   {'n_neighbors': 6, 'weights': 'distance'}           0.399631
# 12    {'n_neighbors': 7, 'weights': 'uniform'}           0.419935
# 13   {'n_neighbors': 7, 'weights': 'distance'}           0.401477
# 14    {'n_neighbors': 8, 'weights': 'uniform'}           0.419935
# 15   {'n_neighbors': 8, 'weights': 'distance'}           0.413013
# 16    {'n_neighbors': 9, 'weights': 'uniform'}           0.420397
# 17   {'n_neighbors': 9, 'weights': 'distance'}           0.416705
# 18   {'n_neighbors': 10, 'weights': 'uniform'}           0.414859
# 19  {'n_neighbors': 10, 'weights': 'distance'}           0.423627
# 20   {'n_neighbors': 11, 'weights': 'uniform'}           0.420397
# 21  {'n_neighbors': 11, 'weights': 'distance'}           0.422243
# 22   {'n_neighbors': 12, 'weights': 'uniform'}           0.410706
# 23  {'n_neighbors': 12, 'weights': 'distance'}           0.416244
# 24   {'n_neighbors': 13, 'weights': 'uniform'}           0.411168
# 25  {'n_neighbors': 13, 'weights': 'distance'}           0.416244
# 26   {'n_neighbors': 14, 'weights': 'uniform'}           0.407937
# 27  {'n_neighbors': 14, 'weights': 'distance'}           0.414398
# 28   {'n_neighbors': 15, 'weights': 'uniform'}           0.405630
# 29  {'n_neighbors': 15, 'weights': 'distance'}           0.411168
# 30   {'n_neighbors': 16, 'weights': 'uniform'}           0.408399
# 31  {'n_neighbors': 16, 'weights': 'distance'}           0.413475
# 32   {'n_neighbors': 17, 'weights': 'uniform'}           0.408860
# 33  {'n_neighbors': 17, 'weights': 'distance'}           0.420397
# 34   {'n_neighbors': 18, 'weights': 'uniform'}           0.415782
# 35  {'n_neighbors': 18, 'weights': 'distance'}           0.422243
# 36   {'n_neighbors': 19, 'weights': 'uniform'}           0.411168
# 37  {'n_neighbors': 19, 'weights': 'distance'}           0.419935
# 38   {'n_neighbors': 20, 'weights': 'uniform'}           0.412090
# 39  {'n_neighbors': 20, 'weights': 'distance'}           0.418090
# 40   {'n_neighbors': 21, 'weights': 'uniform'}           0.419935
# 41  {'n_neighbors': 21, 'weights': 'distance'}           0.424089
# 42   {'n_neighbors': 22, 'weights': 'uniform'}           0.416705
# 43  {'n_neighbors': 22, 'weights': 'distance'}           0.419012
# 44   {'n_neighbors': 23, 'weights': 'uniform'}           0.411629
# 45  {'n_neighbors': 23, 'weights': 'distance'}           0.413936
# 46   {'n_neighbors': 24, 'weights': 'uniform'}           0.410706
# 47  {'n_neighbors': 24, 'weights': 'distance'}           0.413475
# 48   {'n_neighbors': 25, 'weights': 'uniform'}           0.407937
# 49  {'n_neighbors': 25, 'weights': 'distance'}           0.415321
# 50   {'n_neighbors': 26, 'weights': 'uniform'}           0.404707
# 51  {'n_neighbors': 26, 'weights': 'distance'}           0.413475
# 52   {'n_neighbors': 27, 'weights': 'uniform'}           0.400554
# 53  {'n_neighbors': 27, 'weights': 'distance'}           0.413013
# 54   {'n_neighbors': 28, 'weights': 'uniform'}           0.399169
# 55  {'n_neighbors': 28, 'weights': 'distance'}           0.414398
# 56   {'n_neighbors': 29, 'weights': 'uniform'}           0.398246
# 57  {'n_neighbors': 29, 'weights': 'distance'}           0.404707
# 58   {'n_neighbors': 30, 'weights': 'uniform'}           0.401015
# 59  {'n_neighbors': 30, 'weights': 'distance'}           0.402400
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.430748           0.427449         0.421117        0.011363
# 1            0.430748           0.427449         0.421117        0.011363
# 2            0.428440           0.457948         0.421425        0.033036
# 3            0.430748           0.427449         0.421117        0.011363
# 4            0.419206           0.396488         0.404956        0.010137
# 5            0.433518           0.409889         0.415730        0.012824
# 6            0.435365           0.441312         0.425427        0.018410
# 7            0.428901           0.422366         0.416808        0.012760
# 8            0.428901           0.427911         0.426966        0.002075
# 9            0.437673           0.416821         0.419732        0.013617
# 10           0.427978           0.436229         0.425273        0.010223
# 11           0.435826           0.429298         0.421579        0.015754
# 12           0.435365           0.434843         0.430045        0.007155
# 13           0.440443           0.434381         0.425427        0.017123
# 14           0.442752           0.445471         0.436047        0.011452
# 15           0.442290           0.432532         0.429275        0.012174
# 16           0.435365           0.441312         0.432353        0.008800
# 17           0.438135           0.434843         0.429891        0.009424
# 18           0.443675           0.444547         0.434354        0.013796
# 19           0.438135           0.425601         0.429121        0.006425
# 20           0.442290           0.442237         0.434970        0.010310
# 21           0.440443           0.438540         0.433739        0.008170
# 22           0.434903           0.449168         0.431584        0.015876
# 23           0.441828           0.437616         0.431892        0.011203
# 24           0.435826           0.444547         0.430506        0.014136
# 25           0.443675           0.442237         0.434046        0.012608
# 26           0.439982           0.444085         0.430660        0.016162
# 27           0.439520           0.441312         0.431738        0.012289
# 28           0.437211           0.425601         0.422811        0.013045
# 29           0.441828           0.433457         0.428813        0.012942
# 55               34            1.000000            1.000000
# 56               57            0.552194            0.557839
# 57               36            1.000000            1.000000
# 58               47            0.548961            0.557146
# 59               42            1.000000            1.000000
#
#     split2_train_score  mean_train_score  std_train_score
# 0             1.000000          1.000000         0.000000
# 1             1.000000          1.000000         0.000000
# 2             0.822063          0.829308         0.006887
# 3             1.000000          1.000000         0.000000
# 4             0.768059          0.781594         0.009733
# 5             1.000000          1.000000         0.000000
# 6             0.708054          0.719565         0.008151
# 7             1.000000          1.000000         0.000000
# 8             0.690053          0.696015         0.004645
# 9             1.000000          1.000000         0.000000
# 10            0.665820          0.671695         0.006449
# 11            1.000000          1.000000         0.000000
# 12            0.648742          0.656766         0.007644
# 13            1.000000          1.000000         0.000000
# 14            0.630741          0.642683         0.009301
# 15            1.000000          1.000000         0.000000
# 16            0.615047          0.626060         0.007830
# 17            1.000000          1.000000         0.000000
# 18            0.612047          0.622212         0.007884
# 19            1.000000          1.000000         0.000000
# 20            0.602816          0.612438         0.006809
# 21            1.000000          1.000000         0.000000
# 22            0.595200          0.609900         0.010413
# 23            1.000000          1.000000         0.000000
# 24            0.586430          0.599356         0.009140
# 25            1.000000          1.000000         0.000000
# 26            0.587122          0.595507         0.006104
# 27            1.000000          1.000000         0.000000
# 28            0.579275          0.588350         0.006417
# 29            1.000000          1.000000         0.000000
# 30            0.575352          0.586273         0.007861
# 31            1.000000          1.000000         0.000000
# 32            0.571890          0.582963         0.007841
# 33            1.000000          1.000000         0.000000
# 34            0.574660          0.581346         0.004895
# 35            1.000000          1.000000         0.000000
# 36            0.569351          0.574035         0.004201
# 37            1.000000          1.000000         0.000000
# 38            0.567044          0.572958         0.004644
# 39            1.000000          1.000000         0.000000
# 40            0.563813          0.569802         0.005825
# 41            1.000000          1.000000         0.000000
# 42            0.556427          0.565878         0.006839
# 43            1.000000          1.000000         0.000000
# 44            0.553427          0.562492         0.007022
# 45            1.000000          1.000000         0.000000
# 46            0.552273          0.559567         0.005611
# 47            1.000000          1.000000         0.000000
# 48            0.553427          0.558720         0.005410
# 49            1.000000          1.000000         0.000000
# 50            0.548350          0.553641         0.003894
# 51            1.000000          1.000000         0.000000
# 52            0.548581          0.552794         0.006347
# 53            1.000000          1.000000         0.000000
# 54            0.549735          0.553871         0.004512
# 55            1.000000          1.000000         0.000000
# 56            0.537503          0.549179         0.008572
# 57            1.000000          1.000000         0.000000
# 58            0.538195          0.548101         0.007761
# 59            1.000000          1.000000         0.000000

# %%
grid.best_score_
# Out:
# 0.43604740649530555

# %%
grid.best_params_
# Out:
# {'n_neighbors': 8, 'weights': 'uniform'}

# %%
train_sizes, train_scores, validation_scores = learning_curve(estimator=KNeighborsClassifier(n_neighbors=8),X=X, y=y, train_sizes=train_sizes, cv=5, scoring='accuracy')

# %%
train_scores_mean = train_scores.mean(axis=1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label='Training error')
plt.plot(train_sizes, validation_scores_mean, label='Validation Error')

plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('8-NN Learning Curve - Wine', fontsize = 18, y=1.03)
plt.legend()
